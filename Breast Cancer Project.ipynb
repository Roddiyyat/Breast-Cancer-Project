# %% [markdown]
# ### Cleaning and tidying my breast cancer dataset

# %%
# import the neccessary libaries
import pandas as pd 

my_df = pd.read_csv('breast_cancer.csv')

# %% [markdown]
# ### Whenever i get my data, i run some parameters to understand the type of data i'm working with.

# %%
# df.head is used to get the first 5 rows of my data
my_df.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
# df.tail is used to get the last 5 rows of my data
my_df.tail()
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean symmetry  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
# df.columns is used to get the columns in my data
my_df.columns
# Out:
# Index(['Unnamed: 0', 'mean radius', 'mean texture', 'mean perimeter',
#        'mean area', 'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'target'],
#       dtype='object')

# %%
# df.index is used to get access to the number of rows present in our dataset 
my_df.index
# Out:
# RangeIndex(start=0, stop=569, step=1)

# %%
# df.values is used to get the middle segment(numpy representation) of our data
my_df.values
# Out:
# array([[0.000e+00, 1.799e+01, 1.038e+01, ..., 4.601e-01, 1.189e-01,
#         0.000e+00],
#        [1.000e+00, 2.057e+01, 1.777e+01, ..., 2.750e-01, 8.902e-02,
#         0.000e+00],
#        [2.000e+00, 1.969e+01, 2.125e+01, ..., 3.613e-01, 8.758e-02,
#         0.000e+00],
#        ...,
#        [5.660e+02, 1.660e+01, 2.808e+01, ..., 2.218e-01, 7.820e-02,
#         0.000e+00],
#        [5.670e+02, 2.060e+01, 2.933e+01, ..., 4.087e-01, 1.240e-01,
#         0.000e+00],
#        [5.680e+02, 7.760e+00, 2.454e+01, ..., 2.871e-01, 7.039e-02,
#         1.000e+00]])

# %%
# type function is used to understand the type of objects present in our data
type(my_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# df.shape is use to give a total estimate of all our data values
my_df.shape
# Out:
# (569, 32)

# %%
# df.info is used to better understand our dataframe
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               569 non-null    int64
#  1   mean radius              569 non-null    float64
#  2   mean texture             569 non-null    float64
#  3   mean perimeter           569 non-null    float64
#  4   mean area                569 non-null    float64
#  5   mean smoothness          569 non-null    float64
#  6   mean compactness         569 non-null    float64
#  7   mean concavity           569 non-null    float64
#  8   mean concave points      569 non-null    float64
#  9   mean symmetry            569 non-null    float64
#  10  mean fractal dimension   569 non-null    float64
#  11  radius error             569 non-null    float64
#  12  texture error            569 non-null    float64
# ...

# %%
# df.describe does exactly what you think it does; it describes our data(lol)
my_df.describe()
# Out:
#        Unnamed: 0  mean radius  mean texture  mean perimeter    mean area  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean   284.000000    14.127292     19.289649       91.969033   654.889104
# std    164.400426     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%    142.000000    11.700000     16.170000       75.170000   420.300000
# 50%    284.000000    13.370000     18.840000       86.240000   551.100000
# 75%    426.000000    15.780000     21.800000      104.100000   782.700000
# max    568.000000    28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ### Slicing and subsetting our dataset

# %%
my_df['mean area']
# Out:
# 0      1001.0
# 1      1326.0
# 2      1203.0
# 3       386.1
# 4      1297.0
#         ...
# 564    1479.0
# 565    1261.0
# 566     858.1
# 567    1265.0
# 568     181.0
# Name: mean area, Length: 569, dtype: float64

# %%
# creating a new dataframe
mean_df = my_df['mean area']
mean_df.head()
# Out:
# 0    1001.0
# 1    1326.0
# 2    1203.0
# 3     386.1
# 4    1297.0
# Name: mean area, dtype: float64

# %%
# subsetting is used to get a few columns and row from our dataset that we want to work with
subset = my_df[['mean radius', 'mean texture', 'mean perimeter']]
subset.head()
# Out:
#    mean radius  mean texture  mean perimeter
# 0        17.99         10.38          122.80
# 1        20.57         17.77          132.90
# 2        19.69         21.25          130.00
# 3        11.42         20.38           77.58
# 4        20.29         14.34          135.10

# %% [markdown]
# # Indexing and subsetting rows in our dataset

# %%
# using the loc function to subset
my_df.loc[2]
my_df.loc[[2, 0]]


# using iloc
my_df.iloc[2]
my_df.iloc[[2, 0]]
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 2           2        19.69         21.25           130.0     1203.0
# 0           0        17.99         10.38           122.8     1001.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 2           0.1096            0.1599          0.1974               0.1279
# 0           0.1184            0.2776          0.3001               0.1471
#
#    mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 2         0.2069  ...          25.53            152.5      1709.0
# 0         0.2419  ...          17.33            184.6      2019.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 2            0.1444             0.4245           0.4504                0.2430
# 0            0.1622             0.6656           0.7119                0.2654
#
#    worst symmetry  worst fractal dimension  target
# ...

# %%
# getting multiple columns and rows

subset = my_df.loc[:, ['mean radius', 'mean texture', 'mean perimeter']]
subset.head()
# Out:
#    mean radius  mean texture  mean perimeter
# 0        17.99         10.38          122.80
# 1        20.57         17.77          132.90
# 2        19.69         21.25          130.00
# 3        11.42         20.38           77.58
# 4        20.29         14.34          135.10

# %%
my_df.loc[my_df['mean area'] >=1000.0, ['mean area']]
# Out:
#      mean area
# 0       1001.0
# 1       1326.0
# 2       1203.0
# 4       1297.0
# 6       1040.0
# ..         ...
# 535     1308.0
# 563     1347.0
# 564     1479.0
# 565     1261.0
# 567     1265.0
#
# [92 rows x 1 columns]

# %% [markdown]
# Tidying data. What does it mean to tidy a dataset?
# Tyding a dataset is important especially when building a statistical of ML model that can be used prediction.
#
# Occassionaly, we get dataset that we can start analysing immediately, but this isn't always the case; sometime we get messy data that need cleaning.

# %%
# messy data that needs cleaning
my_df2 = pd.read_csv('TCGA_genetic_data.csv')

# %%
my_df2.head()
# Out:
#    ?|100130426  ?|100133144  ?|100134869     ?|10357      ?|10431  ?|136542  \
# 0          0.0    15.453000    17.616300  106.314000  1485.700000       0.0
# 1          0.0    22.623000    24.242000   50.537500   437.975000       0.0
# 2          NaN    19.242386    19.582951  238.958917   614.984166       NaN
# 3          NaN    36.483106    18.490301  365.866320   625.724590       NaN
# 4          0.0    22.410400    37.683300  138.544000   494.356000       0.0
#
#      ?|155060   ?|26823  ?|280660  ?|317712  ...   ZXDA|7789  ZXDB|158586  \
# 0   67.171900  0.344500     0.000       0.0  ...   15.845700   159.835000
# 1  162.181000  0.284000     0.284       0.0  ...   88.049400   681.673000
# 2  210.122583  0.090280       NaN       NaN  ...   52.958904   673.522394
# 3  620.928665  1.769813       NaN       NaN  ...  101.824220   520.069422
# 4  371.901000  0.566900     0.000       0.0  ...   69.164500   310.673000
#
# ...

# %%
my_df2.info
# Out:
# <bound method DataFrame.info of      ?|100130426  ?|100133144  ?|100134869     ?|10357      ?|10431  ?|136542  \
# 0            0.0    15.453000    17.616300  106.314000  1485.700000       0.0
# 1            0.0    22.623000    24.242000   50.537500   437.975000       0.0
# 2            NaN    19.242386    19.582951  238.958917   614.984166       NaN
# 3            NaN    36.483106    18.490301  365.866320   625.724590       NaN
# 4            0.0    22.410400    37.683300  138.544000   494.356000       0.0
# ..           ...          ...          ...         ...          ...       ...
# 495          0.0     2.037500     1.085100  102.795000  1238.100000       0.0
# 496          0.0    11.977000    19.978700  125.616000   734.981000       0.0
# 497          0.0    20.389300    10.756400   87.575100   876.529000       0.0
# 498          NaN     2.645497     9.640453  684.406623  1013.924439       NaN
# 499          0.0     4.788700     5.156600  359.567000   985.579000       0.0
#
# ...

# %% [markdown]
# ### We can classify our dataset as messy because variables are being stored in rows. One of the functions of tidying our data is to reduce the column variable; this can be done by melting.

# %%
# based on the df info output, its safe to assume that our data is a wide data(has lots of columns) 
# we need to convert from wide data(lots of columns) to long data(lots of rows)

#using the pandas melt functtion
# id_vars is for the column we don't want to change
TCGA_long = pd.melt(my_df2, id_vars='bcr_patient_barcode')

TCGA_long.head()
# Out:
#   bcr_patient_barcode     variable value
# 0        TCGA-EK-A2H0  ?|100130426   0.0
# 1        TCGA-J8-A3O1  ?|100130426   0.0
# 2        TCGA-L5-A4OT  ?|100130426   NaN
# 3        TCGA-AB-2935  ?|100130426   NaN
# 4        TCGA-56-8628  ?|100130426   0.0

# %%
TCGA_long = pd.melt(my_df2, id_vars='bcr_patient_barcode',
                    var_name='bcr_biopsy_barcode')

TCGA_long.head()
# Out:
#   bcr_patient_barcode bcr_biopsy_barcode value
# 0        TCGA-EK-A2H0        ?|100130426   0.0
# 1        TCGA-J8-A3O1        ?|100130426   0.0
# 2        TCGA-L5-A4OT        ?|100130426   NaN
# 3        TCGA-AB-2935        ?|100130426   NaN
# 4        TCGA-56-8628        ?|100130426   0.0

# %%
my_df2_melt = pd.melt(my_df2,
    id_vars=['bcr_patient_barcode','bcr_biopsy_barcode'],
    var_name='variables',
    value_name='gen_data',
)

# %%
my_df2_melt.head()
# Out:
#   bcr_patient_barcode            bcr_biopsy_barcode    variables  gen_data
# 0        TCGA-EK-A2H0  TCGA-EK-A2H0-01A-11R-A180-07  ?|100130426       0.0
# 1        TCGA-J8-A3O1  TCGA-J8-A3O1-01A-11R-A21D-07  ?|100130426       0.0
# 2        TCGA-L5-A4OT  TCGA-L5-A4OT-01A-11R-A28J-31  ?|100130426       NaN
# 3        TCGA-AB-2935  TCGA-AB-2935-03A-01T-0740-13  ?|100130426       NaN
# 4        TCGA-56-8628  TCGA-56-8628-01A-11R-2403-07  ?|100130426       0.0

# %%
# splitting rows in our dataset

'TCGA-EK-A2H0-01A-11R-A180-07'.split('_')
# Out:
# ['TCGA-EK-A2H0-01A-11R-A180-07']

# %%
bcr_biopsy_barcode_split = my_df2['bcr_biopsy_barcode'].str.split('_')

bcr_biopsy_barcode_split.head()
# Out:
# 0    [TCGA-EK-A2H0-01A-11R-A180-07]
# 1    [TCGA-J8-A3O1-01A-11R-A21D-07]
# 2    [TCGA-L5-A4OT-01A-11R-A28J-31]
# 3    [TCGA-AB-2935-03A-01T-0740-13]
# 4    [TCGA-56-8628-01A-11R-2403-07]
# Name: bcr_biopsy_barcode, dtype: object

# %%
# now that we've tidyed our data, the next step is to create a new csv file for our dataset

my_df2_melt.to_csv('my_df2.csv', index=False)

# %%
my_df2_melt.head()
# Out:
#   bcr_patient_barcode            bcr_biopsy_barcode    variables  gen_data
# 0        TCGA-EK-A2H0  TCGA-EK-A2H0-01A-11R-A180-07  ?|100130426       0.0
# 1        TCGA-J8-A3O1  TCGA-J8-A3O1-01A-11R-A21D-07  ?|100130426       0.0
# 2        TCGA-L5-A4OT  TCGA-L5-A4OT-01A-11R-A28J-31  ?|100130426       NaN
# 3        TCGA-AB-2935  TCGA-AB-2935-03A-01T-0740-13  ?|100130426       NaN
# 4        TCGA-56-8628  TCGA-56-8628-01A-11R-2403-07  ?|100130426       0.0

# %% [markdown]
# ### The End!
